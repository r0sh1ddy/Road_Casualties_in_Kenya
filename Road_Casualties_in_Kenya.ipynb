# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 1000000)

# %%
df = pd.read_csv('dft-road-casualty-statistics-vehicle-last-5-years.csv',low_memory=False)
df.head()
# Out:
#   collision_index  collision_year collision_ref_no  vehicle_reference  \
# 0   2020552100160            2020        552100160                  1
# 1   2020460936785            2020        460936785                  3
# 2   2020010243652            2020        010243652                  1
# 3   2020410958331            2020        410958331                  1
# 4   2020010260928            2020        010260928                  1
#
#    vehicle_type  towing_and_articulation  vehicle_manoeuvre_historic  \
# 0             2                        0                          18
# 1             9                        0                           3
# 2             9                        0                          18
# 3             9                        0                          18
# 4             9                        0                          99
#
#    vehicle_manoeuvre  vehicle_direction_from  vehicle_direction_to  \
# 0                 19                       2                     6
# 1                  3                       8                     4
# 2                 19                       5                     1
# 3                 19                       5                     1
# 4                 99                       9                     9
#
#    vehicle_location_restricted_lane_historic  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                         99
#
#    vehicle_location_restricted_lane  junction_location  \
# 0                                 0                  0
# 1                                 0                  0
# 2                                 0                  1
# 3                                 0                  0
# 4                                99                  9
#
#    skidding_and_overturning  hit_object_in_carriageway  \
# 0                         0                          0
# 1                         0                          0
# 2                         0                          0
# 3                         5                          0
# 4                         9                         99
#
#    vehicle_leaving_carriageway  hit_object_off_carriageway  \
# 0                            1                           0
# 1                            1                           0
# 2                            0                           0
# 3                            1                           7
# 4                            9                          99
#
#    first_point_of_impact  vehicle_left_hand_drive  \
# 0                      1                        1
# 1                      2                        1
# 2                      1                        1
# 3                      4                        1
# 4                      2                        9
#
#    journey_purpose_of_driver_historic  journey_purpose_of_driver  \
# 0                                   2                          2
# 1                                   5                          6
# 2                                   6                          6
# 3                                   6                          6
# 4                                   6                          6
#
#    sex_of_driver  age_of_driver  age_band_of_driver  engine_capacity_cc  \
# 0              1             20                   4                 125
# 1              1             41                   7                3956
# 2              1             31                   6                3956
# 3              1             23                   5                3956
# 4              1             38                   7                3956
#
#    propulsion_code  age_of_vehicle generic_make_model  driver_imd_decile  \
# 0                1              16                 -1                  2
# 1                2               3                 -1                 10
# 2                2               3                 -1                  2
# 3                2               2                 -1                  7
# 4                2               3                 -1                  5
#
#   lsoa_of_driver  escooter_flag  driver_distance_banding
# 0      E01020575              0                       -1
# 1      E01024778              0                       -1
# 2      E01001477              0                       -1
# 3      E01023391              0                       -1
# 4      E01016494              0                       -1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920692 entries, 0 to 920691
# Data columns (total 32 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   collision_index                            920692 non-null  object
#  1   collision_year                             920692 non-null  int64
#  2   collision_ref_no                           920692 non-null  object
#  3   vehicle_reference                          920692 non-null  int64
#  4   vehicle_type                               920692 non-null  int64
#  5   towing_and_articulation                    920692 non-null  int64
#  6   vehicle_manoeuvre_historic                 920692 non-null  int64
#  7   vehicle_manoeuvre                          920692 non-null  int64
#  8   vehicle_direction_from                     920692 non-null  int64
#  9   vehicle_direction_to                       920692 non-null  int64
#  10  vehicle_location_restricted_lane_historic  920692 non-null  int64
#  11  vehicle_location_restricted_lane           920692 non-null  int64
#  12  junction_location                          920692 non-null  int64
#  13  skidding_and_overturning                   920692 non-null  int64
#  14  hit_object_in_carriageway                  920692 non-null  int64
#  15  vehicle_leaving_carriageway                920692 non-null  int64
#  16  hit_object_off_carriageway                 920692 non-null  int64
#  17  first_point_of_impact                      920692 non-null  int64
#  18  vehicle_left_hand_drive                    920692 non-null  int64
#  19  journey_purpose_of_driver_historic         920692 non-null  int64
#  20  journey_purpose_of_driver                  920692 non-null  int64
#  21  sex_of_driver                              920692 non-null  int64
#  22  age_of_driver                              920692 non-null  int64
#  23  age_band_of_driver                         920692 non-null  int64
#  24  engine_capacity_cc                         920692 non-null  int64
#  25  propulsion_code                            920692 non-null  int64
#  26  age_of_vehicle                             920692 non-null  int64
#  27  generic_make_model                         920692 non-null  object
#  28  driver_imd_decile                          920692 non-null  int64
#  29  lsoa_of_driver                             920692 non-null  object
#  30  escooter_flag                              920692 non-null  int64
#  31  driver_distance_banding                    920692 non-null  int64
# dtypes: int64(28), object(4)
# memory usage: 224.8+ MB
